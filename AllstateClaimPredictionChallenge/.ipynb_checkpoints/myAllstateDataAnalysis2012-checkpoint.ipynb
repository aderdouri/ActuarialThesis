# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score as AUC
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, LabelBinarizer

from scipy import stats
import seaborn as sns
from copy import deepcopy

# %matplotlib inline

# %%
# !ls -lhtr
# Out:
# total 982296
# -rw-rw-r--@ 1 aderdouri  staff    24K Dec 11  2019 dictionary.html
# -rw-rw-r--@ 1 aderdouri  staff   4.9M Dec 11  2019 example_compressed_entry.zip
# -rw-rw-r--@ 1 aderdouri  staff   111M Dec 11  2019 test_set.zip
# -rw-rw-r--@ 1 aderdouri  staff   363M Dec 11  2019 train_set.zip
# -rw-r--r--@ 1 aderdouri  staff   925K May 11 17:12 myAllstateDataAnalysis2012.ipynb

# %%
# !ls -ltr ActuarialThesis/ClaimPredictionChallenge
# Out:
# ls: ActuarialThesis/ClaimPredictionChallenge: No such file or directory

# %%
# !pip install dask

# %%
import time

# %%
from dask import dataframe as dd
start = time.time()
dask_df = dd.read_csv('ActuarialThesis/ClaimPredictionChallenge/train_set.zip')
end = time.time()
print("Read csv with dask: ",(end-start),"sec")
# Out:
# Read csv with dask:  0.028095245361328125 sec
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py:543: UserWarning: Warning zip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(

# %%
dask_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py:194: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
len(dask_df)
# Out:
# 13184290

# %%
dask_df['Class'] = dask_df['Claim_Amount'].map(lambda amt: 1 if amt==0.0 else 0)

# %%
neg, pos = np.bincount(dask_df['Class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py:194: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-89a3f1e12e75> in <cell line: 1>()
# ----> 1 neg, pos = np.bincount(dask_df['Class'])
#       2 total = neg + pos
#       3 print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
#       4     total, pos, 100 * pos / total))
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in bincount(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in __array__(self, dtype, **kwargs)
#     495
#     496     def __array__(self, dtype=None, **kwargs):
# --> 497         self._computed = self.compute()
#     498         x = np.array(self._computed)
#     499         return x
#
# /usr/local/lib/python3.10/dist-packages/dask/base.py in compute(self, **kwargs)
#     313         dask.base.compute
#     314         """
# --> 315         (result,) = compute(self, traverse=False, **kwargs)
#     316         return result
#     317
#
# /usr/local/lib/python3.10/dist-packages/dask/base.py in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     598         postcomputes.append(x.__dask_postcompute__())
#     599
# --> 600     results = schedule(dsk, keys, **kwargs)
#     601     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     602
#
# /usr/local/lib/python3.10/dist-packages/dask/threaded.py in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      87             pool = MultiprocessingPoolExecutor(pool)
#      88
# ---> 89     results = get_async(
#      90         pool.submit,
#      91         pool._max_workers,
#
# /usr/local/lib/python3.10/dist-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509                             _execute_task(task, data)  # Re-execute locally
#     510                         else:
# --> 511                             raise_exception(exc, tb)
#     512                     res, worker_id = loads(res_info)
#     513                     state["cache"][key] = res
#
# /usr/local/lib/python3.10/dist-packages/dask/local.py in reraise(exc, tb)
#     317     if exc.__traceback__ is not tb:
#     318         raise exc.with_traceback(tb)
# --> 319     raise exc
#     320
#     321
#
# /usr/local/lib/python3.10/dist-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222     try:
#     223         task, data = loads(task_info)
# --> 224         result = _execute_task(task, data)
#     225         id = get_id()
#     226         result = dumps((result, id))
#
# /usr/local/lib/python3.10/dist-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.10/dist-packages/dask/optimization.py in __call__(self, *args)
#     988         if not len(args) == len(self.inkeys):
#     989             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 990         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#     991
#     992     def __reduce__(self):
#
# /usr/local/lib/python3.10/dist-packages/dask/core.py in get(dsk, out, cache)
#     147     for key in toposort(dsk):
#     148         task = dsk[key]
# --> 149         result = _execute_task(task, cache)
#     150         cache[key] = result
#     151     result = _execute_task(out, cache)
#
# /usr/local/lib/python3.10/dist-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py in __call__(self, part)
#     139
#     140         # Call `pandas_read_text`
# --> 141         df = pandas_read_text(
#     142             self.reader,
#     143             block,
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     194     df = reader(bio, **kwargs)
#     195     if dtypes:
# --> 196         coerce_dtypes(df, dtypes)
#     197
#     198     if enforce and columns and (list(df.columns) != list(columns)):
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/io/csv.py in coerce_dtypes(df, dtypes)
#     295             rule.join(filter(None, [dtype_msg, date_msg]))
#     296         )
# --> 297         raise ValueError(msg)
#     298
#     299
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------------+---------+----------+
# | Column       | Found   | Expected |
# +--------------+---------+----------+
# | Claim_Amount | float64 | int64    |
# | OrdCat       | object  | int64    |
# +--------------+---------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - OrdCat
#   ValueError("invalid literal for int() with base 10: '?'")
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Claim_Amount': 'float64',
#        'OrdCat': 'object'}
#
# to the call to `read_csv`/`read_table`.

# %%
import pandas as pd
test_data = pd.read_csv('ActuarialThesis/ClaimPredictionChallenge/train_set.zip', low_memory=False)
test_data.head()
# Out:
#      Row_ID  Household_ID  Vehicle  Calendar_Year  Model_Year Blind_Make  \
# 0  13184291         11885        1           2008        2001          P
# 1  13184292         11885        1           2009        2001          P
# 2  13184293         11887        1           2008        2003          Y
# 3  13184294         11887        1           2009        2003          Y
# 4  13184295         11888        1           2008        2006         AU
#
#   Blind_Model Blind_Submodel Cat1 Cat2  ...      Var4      Var5      Var6  \
# 0        P.24         P.24.0    A    C  ...  1.669468  0.330938  0.430648
# 1        P.24         P.24.0    A    C  ...  1.669468  0.330938  0.430648
# 2        Y.29         Y.29.0    B    C  ... -0.191039  0.527193 -0.231408
# 3        Y.29         Y.29.0    B    C  ... -0.191039  0.527193 -0.231408
# 4       AU.14        AU.14.1    B    A  ... -0.275608  0.069263 -0.685256
#
#        Var7      Var8 NVCat   NVVar1    NVVar2    NVVar3    NVVar4
# 0 -0.886198  3.461982     N -0.23153 -0.266117  2.715490 -0.251419
# 1 -0.886198  3.461982     M -0.23153 -0.266117 -0.272337 -0.251419
# 2 -0.665021 -0.131601     O -0.23153 -0.266117 -0.272337 -0.251419
# 3 -0.665021 -0.131601     O -0.23153 -0.266117 -0.272337 -0.251419
# 4 -0.591295 -0.163872     O -0.23153 -0.266117 -0.272337 -0.251419
#
# [5 rows x 34 columns]

# %%
train_set_chunks = pd.read_csv('ActuarialThesis/ClaimPredictionChallenge/train_set.zip', chunksize=700_000)
train_df = next(train_set_chunks)

# %%
len(train_df)
# Out:
# 700000

# %%
train_df.head()
# Out:
#    Row_ID  Household_ID  Vehicle  Calendar_Year  Model_Year Blind_Make  \
# 0       1             1        3           2005        2005          K
# 1       2             2        2           2005        2003          Q
# 2       3             3        1           2005        1998         AR
# 3       4             3        1           2006        1998         AR
# 4       5             3        2           2005        2001          D
#
#   Blind_Model Blind_Submodel Cat1 Cat2  ...      Var5      Var6      Var7  \
# 0        K.78         K.78.2    D    C  ...  1.008912  0.261040  0.907793
# 1        Q.22         Q.22.3    B    C  ...  1.240851  0.432987 -0.726459
# 2       AR.41        AR.41.1    B    ?  ... -0.971487 -1.405797 -0.837048
# 3       AR.41        AR.41.1    B    ?  ... -0.971487 -1.405797 -0.837048
# 4        D.20         D.20.0    J    C  ...  0.812656  2.112691  1.534462
#
#        Var8 NVCat   NVVar1    NVVar2    NVVar3    NVVar4 Claim_Amount
# 0 -0.077998     M -0.23153 -0.266117 -0.272337 -0.251419          0.0
# 1  0.204785     O -0.23153 -0.266117 -0.272337 -0.251419          0.0
# 2 -1.176858     F -0.23153 -0.266117 -0.272337 -0.251419          0.0
# 3 -1.176858     F -0.23153 -0.266117 -0.272337 -0.251419          0.0
# 4  2.347260     F -0.23153 -0.266117 -0.272337 -0.251419          0.0
#
# [5 rows x 35 columns]

# %%
len(train_df[train_df['Claim_Amount']==0.0]) / len(train_df)
# Out:
# 0.9914514285714285

# %%
a = train_df['Claim_Amount'].skew()
print('Skewness of loss feature is :', a)
# Out:
# Skewness of loss feature is : 63.77029356381702

# %%
train_df['Class'] = train_df['Claim_Amount'].map(lambda amt: 1 if amt==0.0 else 0)

# %%
neg, pos = np.bincount(train_df['Class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 700000
#     Positive: 694016 (99.15% of total)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(16,5)

ax1.hist(train_df['Claim_Amount'], bins=50)
ax1.set_title('Train Claim_Amount')

#ax2.hist(np.log(train_data['loss']), bins=50, color='g')
#ax2.set_title('Train Log Loss')

#ax3.hist(np.log(train_data['loss']+200), bins=50, color='g')
#ax3.set_title('Train Log Loss with shift')
plt.show()

# %% [markdown]
# ## Chargement des données
# * Charger le train dataset dans le dataframe df_train
# * Charger le test dataset dans le dataframe df_test

# %%
train_data = pd.read_csv('ActuarialThesis/AllstateClaimsSeverityData/train.csv.zip')
train_data.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
test_data = pd.read_csv('ActuarialThesis/AllstateClaimsSeverityData/test.csv.zip')
test_data.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# 0   4    A    B    A    A    A    A    A    A    B  ...  0.281143  0.466591
# 1   6    A    B    A    B    A    A    A    A    B  ...  0.836443  0.482425
# 2   9    A    B    A    B    B    A    B    A    B  ...  0.718531  0.212308
# 3  12    A    A    A    A    B    A    A    A    A  ...  0.397069  0.369930
# 4  15    B    A    A    A    A    B    A    A    A  ...  0.302678  0.398862
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13    cont14
# 0  0.317681  0.61229  0.34365  0.38016  0.377724  0.369858  0.704052  0.392562
# 1  0.443760  0.71330  0.51890  0.60401  0.689039  0.675759  0.453468  0.208045
# 2  0.325779  0.29758  0.34365  0.30529  0.245410  0.241676  0.258586  0.297232
# 3  0.342355  0.40028  0.33237  0.31480  0.348867  0.341872  0.592264  0.555955
# 4  0.391833  0.23688  0.43731  0.50556  0.359572  0.352251  0.301535  0.825823
#
# [5 rows x 131 columns]

# %% [markdown]
# ## Remarques:
# * Train dataset :  188318 observations et 132 caractéristiques/colonnes, avec la vraibale d'intérêt ou cible loss (target variable).
# * Test dataset : 129446 observations et 132 caractéristiques/colonnes. La vraibale d'intérêt ou cible (target variable) a été supprimée.
# * Toutes les caractéristiques (nom significatif des colonnes) ont été annonymisées.

# %% [markdown]
# ## Considérer ce problème comme un problème d'apprentissage automatique.
# * Le dataset train contient des variables categoriques et des variables continues.
# * La variable cible (target variable) est la variable loss (claim severity) qui est une variable continue, on peut donc considérer le problème comme un problème de régression.
# * C'est une problème de d'apprentissage automatique supervisé car on a la variable cible dans le train dataset..
# * BUT: Notre tâche consiste à prédir le montant d'un sinistre (claim severity) pour un nouveau assuré par apprentissage sur les données observées dans le dataset train.

# %% [markdown]
# ## Obtenir une vue d'ensemble des données.

# %%
print("Train dataset vue d'ensemble:")
print(train_data.info())
print('-'*50)
print("Test dataset vue d'ensemble:")
print(test_data.info())
# Out:
# Train dataset vue d'ensemble:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188318 entries, 0 to 188317
# Columns: 132 entries, id to loss
# dtypes: float64(15), int64(1), object(116)
# memory usage: 189.7+ MB
# None
# --------------------------------------------------
# Test dataset vue d'ensemble:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125546 entries, 0 to 125545
# Columns: 131 entries, id to cont14
# dtypes: float64(14), int64(1), object(116)
# memory usage: 125.5+ MB
# None

# %% [markdown]
# ## Observations:
# * En excluant la variable cible `loss` et la variable `Id` le train dataset contient un totale de 130 variables/caractéristiques. Ces variables contiennet des variables catégoriques et d'autres numériques.
# * Sur un totla de 130 variable, 116 sont catégoriques et 14 sont numériques. On remarque qu'on a pas de valeurs manquantes (missing values) dans le train dataset. La companie Allstate a déja procédé à un pré-processing des données..

# %% [markdown]
# ## Séparation variables catégoriques vs variables numériques.

# %%
categorical_features = list(train_data.select_dtypes(include=['object']).columns)
print("Categorical features in Train data : {} features".format(len(categorical_features)))
# Out:
# Categorical features in Train data : 116 features

# %%
continous_features = [i for i in list(train_data.select_dtypes(include=['float64', 'int64']).columns) if i not in ['loss', 'id']]
print("Continuous features in Train data : {} features".format(len(continous_features)))
# Out:
# Continuous features in Train data : 14 features

# %% [markdown]
# ## Vérification des valeurs manquantes (missing values) dans train dataset.

# %%
print('Missing values in Train data:', pd.isnull(train_data).values.any())
print('Missing values in Test  data:', pd.isnull(test_data).values.any())
# Out:
# Missing values in Train data: False
# Missing values in Test  data: False

# %% [markdown]
# ## Observation:
# * Comme on a pas de valeurs manquantes, on peut dire que le dataset à été au préalable pre-processé.
# * En présence de valeurs manquantes, il va falloir suivre les téchniques de remplissage de ces valeurs avant de passeer le dataset aux algorithmes d'apprentissage.

# %% [markdown]
# ## Valeurs uniques dans les caractéristiques catégorielles
# * Déterminer le nombre de valeurs uniques présentes dans chaque caractéristique catégorielle et les charger dans un dataframe.

# %%
unique_in_categorical = []
for i in categorical_features:
    unique_in_categorical.append(len(train_data[i].unique()))

# Création d'un dataframe contenant le nombre de valeurs uniques et les noms des caractéristiques correspondantes.
unique_categories = pd.DataFrame()
unique_categories['category name'] = categorical_features
unique_categories['unique_values'] = unique_in_categorical
print(unique_categories.head())
# Out:
#   category name  unique_values
# 0          cat1              2
# 1          cat2              2
# 2          cat3              2
# 3          cat4              2
# 4          cat5              2

# %%
a=max(unique_categories['unique_values'])
print('Le nombre maximum de valeurs uniques dans une seule caractéristique catégorielle est de :',a)
# Out:
# Le nombre maximum de valeurs uniques dans une seule caractéristique catégorielle est de : 326

# %% [markdown]
# ## Remarques:
# - Il y a beaucoup de caractéristiques qui ont très peu de valeurs uniques.
# - Une caractéristique catégorique a un nombre maximal de valeurs uniques de 326.

# %%
x = unique_categories[unique_categories.unique_values >= 10]
print(x.shape)
# Out:
# (17, 2)

# %% [markdown]
# ## Observation:
# * There are only 17 categorical features in which they have more than 10 unique values in them

# %% [markdown]
# ## Plots for unique values in features.

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

fig.set_size_inches(16,5)
ax1.hist(unique_categories.unique_values, bins=50)
ax1.set_title('Categorical featurs vs Unique values ')
ax1.set_xlabel('Unique values in a feature')
ax1.set_ylabel('Features')


values = unique_categories[unique_categories.unique_values <= 25].unique_values
ax2.set_xlim(1,25)
ax2.hist(values, bins=30)
ax2.set_title('Zooming left part of histogram')
ax2.set_xlabel('Unique values in a feature')
ax2.set_ylabel('Features')
ax2.grid(True)

# %% [markdown]
# ## Observation:
# * From the above plto we noticed that there are alost 100 features which have less than 10 unique values in each feature.
# * There is a feature which have more than 300 unique values in it,and we have seen that in above code as well.
# * Tried to plot the zoomed image to see how these distributions occur, we can see that there are very few number of features that has more number of unique values.

# %% [markdown]
# ## Plots for continous features.

# %%
train_data[continous_features].hist(bins=50, figsize=(16,12));

# %% [markdown]
# ## Observation:
# * we can notice that distributions of each of the continuous features vary a lot.
# * There are a lot of spikes in each of the plots. so ther is no uniformity in PDF Of these continous features.
# * cont2 feature is actually looking like a normal distribution but we cant talk about what is that feature as theya are made anonymous

# %% [markdown]
# ## Checking Box plot of continous features

# %%
for i in continous_features:
    plt.figure(figsize = (10, 0.5))
    sns.boxplot(x = train_data[i],width = 0.5,linewidth = 1.0, showfliers = True)

# %% [markdown]
# ## Observations:
# * we can see that most of the mean values for the continous fearures are lying around 0.5.
# * all values lie between 0 and 1.
# * it shows that data is already normalized.

# %% [markdown]
# ## Checking Describe function on continous features.

# %%
train_data[continous_features].describe()
# Out:
#                cont1          cont2          cont3          cont4  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.493861       0.507188       0.498918       0.491812
# std         0.187640       0.207202       0.202105       0.211292
# min         0.000016       0.001149       0.002634       0.176921
# 25%         0.346090       0.358319       0.336963       0.327354
# 50%         0.475784       0.555782       0.527991       0.452887
# 75%         0.623912       0.681761       0.634224       0.652072
# max         0.984975       0.862654       0.944251       0.954297
#
#                cont5          cont6          cont7          cont8  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.487428       0.490945       0.484970       0.486437
# std         0.209027       0.205273       0.178450       0.199370
# min         0.281143       0.012683       0.069503       0.236880
# 25%         0.281143       0.336105       0.350175       0.312800
# 50%         0.422268       0.440945       0.438285       0.441060
# 75%         0.643315       0.655021       0.591045       0.623580
# max         0.983674       0.997162       1.000000       0.980200
#
#                cont9         cont10         cont11         cont12  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.485506       0.498066       0.493511       0.493150
# std         0.181660       0.185877       0.209737       0.209427
# min         0.000080       0.000000       0.035321       0.036232
# 25%         0.358970       0.364580       0.310961       0.311661
# 50%         0.441450       0.461190       0.457203       0.462286
# 75%         0.566820       0.614590       0.678924       0.675759
# max         0.995400       0.994980       0.998742       0.998484
#
#               cont13         cont14
# count  188318.000000  188318.000000
# mean        0.493138       0.495717
# std         0.212777       0.222488
# min         0.000228       0.179722
# 25%         0.315758       0.294610
# 50%         0.363547       0.407403
# 75%         0.689974       0.724623
# max         0.988494       0.844848

# %% [markdown]
# ## Observation:
# * we noticed that mean value of all continous features is around 0.5 whihc is really good and we can say that Allstate did pre processing and then gave the data.
# * All the contious features are in range of [0,1] whcih is really good.

# %% [markdown]
# ## Checking correlation between continous features.

# %%
plt.subplots(figsize=(16,9))
correlation_matrix = train_data[continous_features].corr()
sns.heatmap(correlation_matrix, annot=True,vmin=0, vmax=1,linewidths=.5);

# %% [markdown]
# ## Observation:
# * In the above heat man we can notice that light colour block indicates high correlation and dark color indicates less similrity.
# * There are a couple of features which are higly correlated. for example see cont 14 and cont 12 - they have a correlation value of 0.99 which is almost the max that it can get.
# * so we can drop some features which are highly correlated and train model to see if it hits in any performance drop.
# * On the other hand as we dont know anything specific abotu data or the feature names we cant blinldly go an drop features. it might result in worse models as well.
# * so tacking these kinds of data is a bit tough. we actually need to train model with and without drop in models and have to decide what is right thing to do.
# * Cont11 and Cont12 are very well coreleated. im thinking to drop atleast one of those features.

# %% [markdown]
# ## Analyse de la variable cible (Target variable)

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data['id'],train_data['loss'])
plt.xlabel('id')
plt.ylabel('loss')
plt.title('loss vs id')
plt.show()

# %% [markdown]
# ## Observation:
# * we can notice that there are several spikes in the plot of loss feature which represents a huge loss at some time.
# * As there are many peaks that we notice we can say that the actual data of this feature is skewed and this can result in suboptimal performance of regression models that we build.
# * skewed data effects a lof in your performance.

# %% [markdown]
# ## Calculate skewness and see how we can reduce skewness.

# %%
a = train_data['loss'].skew()
print('Skewness of loss feature is :',a)
# Out:
# Skewness of loss feature is : 3.7949583775378604

# %%
train_data['logloss'] = np.log(train_data['loss'])
print('Skewness of loss feature after applying log function :',train_data['logloss'].skew())
train_data = train_data.drop(['logloss'],axis = 1)
# Out:
# Skewness of loss feature after applying log function : 0.09297454555136214

# %%
min(train_data['loss'])
# Out:
# 0.67

# %% [markdown]
# ## Observation:
# * we can see that there is a lot of skewness in the target variable and this will result in wrong predictions.
# * we applied log transformation over that target variable and noticed that skewness has decreased a lot.

# %% [markdown]
# ## Plots for target variable before and after log transformation

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.set_size_inches(16,5)

ax1.hist(train_data['loss'], bins=50)
ax1.set_title('Train Loss')

ax2.hist(np.log(train_data['loss']), bins=50, color='g')
ax2.set_title('Train Log Loss')

ax3.hist(np.log(train_data['loss']+200), bins=50, color='g')
ax3.set_title('Train Log Loss with shift')
plt.show()

# %% [markdown]
# ## Observation:
# * First plot consists of target variable distribution with the actual values given in the data set. we noticed that the distribution is not uniform.
# * second plot consists of loss feature after applying log transformation adn we cna observe that this distribution is kind of normal distribution. although mean is not centered to zero , its a lot batter than actual target values in the given dataset.
# * When we added a shift value of 200 we can see that the distribution is actually very nice.

# %% [markdown]
# ## Box plot of target variable

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

fig.set_size_inches(14,5)
ax1.boxplot(train_data['loss'])
ax1.set_ylabel('loss')
ax1.set_title('Box plot of loss feature')


#values = uniq_values_in_categories[uniq_values_in_categories.unique_values <= 25].unique_values
ax2.set_ylim(1,10000)
ax2.boxplot(train_data['loss'])
ax2.set_ylabel('loss')
ax2.set_title('Zoomed version of loss feature')
# Out:
# Text(0.5, 1.0, 'Zoomed version of loss feature')

# %% [markdown]
# ## Observation:
# * We can immeditely notice that most of the 25, 50 ,75 th percentile values are very less. There are a couple of points where loss is very high, usuallly we treat those as outliers but in this case we have to handle those as at that point the company incurred a huge loss.
# * we should be very careful that we dont overfit our model because of these kinds of points.

# %% [markdown]
# ## Checking Train and Test distributions
# * We need to check weather both train and test data are from siilar distributions or not. If we do confirm that data is distributed equally we can do test train split for cv as well
# * There are so many techniques to check distributions on train and test like welchs test, but they need to be done on feature by feature checking.
# * so what we will do is merge both test and train data, include a new target variable as 1 for train and 0 for test data and build a model.
# * if model performs very bad that means both came from similar distributions.

# %% [markdown]
# ### Preparing the data

# %%
#Removing last column in test data which we need to predict. It has Nan values in the given dataset.
train_data_dropped = train_data.drop(['id','loss'], axis=1)
test_data_dropped  = test_data.drop(['id'], axis=1)

print('Shape of Train data :',train_data_dropped.shape)
print('Shape of Test  data :',test_data_dropped.shape)
# Out:
# Shape of Train data : (188318, 130)
# Shape of Test  data : (125546, 130)

# %%
#Now we create a label for test and train data as 0 , 1 respectively.
train_data_dropped['target'] = 1
test_data_dropped['target'] = 0
final_df = pd.concat((train_data_dropped,test_data_dropped))

# %%
data_label_encode = deepcopy(final_df)
for c in range(len(categorical_features)):
    data_label_encode[categorical_features[c]] = data_label_encode[categorical_features[c]].astype('category').cat.codes
print('Shape of data after Label Encoding is  :',data_label_encode.shape)
# Out:
# Shape of data after Label Encoding is  : (313864, 131)

# %%
# One hot encoding and dropping index
data_ohe = pd.get_dummies(data=data_label_encode, columns=categorical_features)
data_ohe.reset_index(drop = True, inplace = True)
print('Shape of data after OHE :',data_ohe.shape)
# Out:
# Shape of data after OHE : (313864, 1191)

# %%
# Shuffling the rows in dataset
from sklearn.utils import shuffle
data_label_encode = shuffle(data_label_encode)

# %%
x = data_label_encode.drop(['target'],axis = 1)
y = data_label_encode.target

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test =  train_test_split(x,y,test_size = 0.3)

print('shape of x_train : ',x_train.shape)
print('shape of y_train : ',y_train.shape)
print('shape of x_test  : ',x_test.shape)
print('shape of y_test  : ',y_test.shape)
# Out:
# shape of x_train :  (219704, 130)
# shape of y_train :  (219704,)
# shape of x_test  :  (94160, 130)
# shape of y_test  :  (94160,)

# %% [markdown]
# ## Building A model

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
predicted_value = model.predict(x_test)
auc = AUC(y_test, predicted_value)
print("Logistic Regression AUC score is : {:.2%}".format(auc))
# Out:
# Logistic Regression AUC score is : 50.00%
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
model = RandomForestClassifier(n_estimators=100, n_jobs=-1)
model.fit(x_train, y_train)
predicted_value = model.predict(x_test)
auc = AUC(y_test, predicted_value)
print("Random Forest AUC: {:.2%}".format(auc))
# Out:
# Random Forest AUC: 50.13%

# %% [markdown]
# ## Observation
# * As you can see both Linear Regression and Random Forest model gives an AUC of 50%. so we can say that both train and test data have similar distributions and it is hard to seperate both when mixed together.

# %% [markdown]
# ## Feature Importance

# %%
# https://github.com/brunocampos01/allstate-claims-severity/blob/master/notebooks/1-data-exploration-and-data-cleaning.ipynb

features = [col for col in train_data.columns if col not in ['id','loss']]
feature_imp_dict = dict(zip(features,model.feature_importances_))
imp_features = sorted(feature_imp_dict,key=feature_imp_dict.get, reverse=True)
imp_feature_values = [feature_imp_dict[x] for x in imp_features]

fea_imp_df = pd.DataFrame(data={'feature': imp_features, 'importance': imp_feature_values})
print(fea_imp_df.head())
# Out:
#   feature  importance
# 0  cont14    0.078168
# 1  cat112    0.053026
# 2   cont7    0.038814
# 3  cat100    0.038733
# 4   cont6    0.029449

# %%
fig,ax = plt.subplots()
plt.xticks(rotation='vertical')

fig.set_size_inches(18,10)
sns.barplot(data=fea_imp_df.iloc[-10:], 
            x="feature", 
            y="importance", 
            ax=ax)
ax.set(xlabel="Feature Name",
       ylabel='Importance',
       title="Variable Importances")
# Out:
# [Text(0, 0.5, 'Importance'),
#  Text(0.5, 0, 'Feature Name'),
#  Text(0.5, 1.0, 'Variable Importances')]

# %% [markdown]
# ## Observation:
# * You cn observe that last few features lik cat62,cat64,ct70,cat22,...... these have very less feature importance when you trained model on combined test data and train data.

# %% [markdown]
# ## PCA

# %%
pd.set_option('display.max_columns', 1000)
#pd.set_option('display.max_rows',1000)

# %%
data_label_encode = shuffle(data_label_encode)
X = data_label_encode.iloc[:, :130]
Y = data_label_encode.iloc[:, 130:]
pca = PCA(n_components = 2)
reduced_X = pca.fit_transform(X)

plt.figure(figsize = (10,10))
plt.scatter(reduced_X[:,0],reduced_X[:,1],c = np.array(y))
plt.title('PCA of features')
plt.xlabel('component-1')
plt.ylabel('component-2')
plt.show()

# %% [markdown]
# ## Observation:
# * we can notice that we can t seperate data easily even with PCA that embedded on 2 components.
